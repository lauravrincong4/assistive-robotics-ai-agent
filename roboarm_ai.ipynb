# %%
import os
import json
import fitz  # PyMuPDF
import re
import concurrent.futures
from langchain_ollama import OllamaLLM
from langchain.prompts import PromptTemplate
from langchain.text_splitter import RecursiveCharacterTextSplitter
from pprint import pprint

# %%
# === 1. Extract text from PDFs ===
def extract_text_by_pages(folder_path):
    texts = {}
    for file in os.listdir(folder_path):
        if file.endswith(".pdf"):
            path = os.path.join(folder_path, file)
            with fitz.open(path) as doc:
                texts[file] = [page.get_text() for page in doc]
    return texts

# %%
# === 2. Relevance Filter ===
def is_relevant_page(text):
    keywords = [
        "robot arm", "manipulator", "structure", "gripper", "end-effector", "assistance", "assistive",
        "domestic tasks", "elderly care", "inflatable", "PAM",
        "brazo robótico", "estructura", "manipulador", "pinza", "efector final", "asistencia", "inflable"
    ]
    return any(k in text.lower() for k in keywords)

# %%
# === 3. Clean noisy content from chunks ===
def clean_chunk_text(text):
    text = re.sub(r"\$[^$]*\$", "", text)
    text = re.sub(r"\[.*?\]", "", text)
    text = re.sub(r"\(fig\.?.*?\)", "", text, flags=re.IGNORECASE)
    text = re.sub(r"\{.*?\}", "", text)
    return text

# %%
# === 4. Robust JSON parser ===
def clean_json_response(text):
    try:
        start = text.find("{")
        end = text.rfind("}") + 1
        return json.loads(text[start:end])
    except:
        return None

# %%
# === 5. Prompt Templates (EN & ES) ===
template_en = """
You are an expert in assistive robotics. Analyze the following text and extract:

1. Types of robotic arm structures — including Cartesian, SCARA, Articulated, Delta, Dual-arm, inflatable arms, PAM-based arms, soft robotic arms. Include inferred structures if not named explicitly.
2. Types of grippers — such as parallel 2-finger, adaptive 3-finger, soft, vacuum, suction, magnetic. Include functional descriptions.
3. For each one, list: Pros, Cons, Applications in domestic assistive robotics.

Return a valid JSON object:
{{
  "arms": [...],
  "grippers": [...]
}}

Text:
{{doc}}
"""

template_es = """
Eres un experto en robótica asistencial. Analiza el siguiente texto y extrae:

1. Tipos de estructuras de brazo robótico — incluyendo cartesiano, SCARA, articulado, delta, brazo dual, brazos inflables, brazos PAM, brazos blandos. Incluye estructuras inferidas si no están nombradas explícitamente.
2. Tipos de grippers — como pinza de 2 dedos, de 3 dedos adaptativo, suaves, por vacío, de succión, magnéticos. Incluye descripciones funcionales.
3. Para cada uno, lista: Ventajas, Desventajas, Aplicaciones en asistencia doméstica.

Devuelve un objeto JSON válido:
{{
  "arms": [...],
  "grippers": [...]
}}

Texto:
{{doc}}
"""

# %%
# === 6. Folder Setup and Model Config ===
pdf_folder = "/mnt/c/Users/laura/OneDrive - unimilitar.edu.co/Documentos/Proyecto de grado/AI_agent/Artículos"
cache_path = "results_cache.json"
llm = OllamaLLM(model="llama2:7b-chat", temperature=0.2)

# %%
# === 7. Load PDFs and filter relevant pages ===
docs_by_page = extract_text_by_pages(pdf_folder)
joined_docs = {
    name: " ".join([p for p in pages if is_relevant_page(p)])
    for name, pages in docs_by_page.items()
    if pages
}

# Diagnostic check
for name, content in joined_docs.items():
    print(f"📘 {name}: {len(content)} characters of relevant content")
# Out:
# 📘 1-s2.0-S0921889025000703-main.pdf: 47242 characters of relevant content
# 📘 1-s2.0-S221478532205307X-main.pdf: 26574 characters of relevant content
# 📘 1-s2.0-S2405896321018991-main.pdf: 20150 characters of relevant content
# 📘 131467.pdf: 14387 characters of relevant content
# 📘 1cd20f074aaf0287a4bbcaceebb585fd3e71.pdf: 26829 characters of relevant content
# 📘 2020-J-RAL-OmniGripper.pdf: 40393 characters of relevant content
# 📘 2109.10892v3.pdf: 41754 characters of relevant content
# 📘 2401.10702v1.pdf: 43263 characters of relevant content
# 📘 3711936.pdf: 132119 characters of relevant content
# 📘 actuators-14-00124.pdf: 53294 characters of relevant content
# 📘 annurev-control-060117-105003.pdf: 83610 characters of relevant content
# 📘 Article SOFMER_CharlotteLEGOFF.pdf: 27503 characters of relevant content
# 📘 ASSISTIVE ROBOTIC ARM.pdf: 25209 characters of relevant content
# 📘 cooper2020.pdf: 30590 characters of relevant content
# 📘 Design_and_Development_of_a_Prototype_Robotic_Grip.pdf: 11418 characters of relevant content
# 📘 e37ije1673.pdf: 31839 characters of relevant content
# 📘 electronics-10-00793-v2.pdf: 53717 characters of relevant content
# 📘 fnbot-18-1337608.pdf: 76511 characters of relevant content
# 📘 frobt-06-00147.pdf: 82308 characters of relevant content
# 📘 gushi2020.pdf: 14156 characters of relevant content
# 📘 Humanoid robots for assisting people with physical disabilities in activities of daily living  A scoping review.pdf: 102411 characters of relevant content
# 📘 icce24.pdf: 11330 characters of relevant content
# 📘 IRJET_Pick_and_Place_Robotic_Arm_A_Revie.pdf: 42470 characters of relevant content
# 📘 li-et-al-2022-a-review-on-structural-development-and-recognition-localization-methods-for-end-effector-of-fruit.pdf: 104919 characters of relevant content
# 📘 PAPRAS_Plug-And-Play_Robotic_Arm_System.pdf: 37648 characters of relevant content
# 📘 ReMAR2024_Murgia_Long_Caro.pdf: 32318 characters of relevant content
# 📘 robotics-11-00127-v2.pdf: 87505 characters of relevant content
# 📘 robotics-12-00005-v2.pdf: 86843 characters of relevant content
# 📘 s10846-022-01781-3.pdf: 50308 characters of relevant content
# 📘 s12369-021-00816-3.pdf: 102228 characters of relevant content
# 📘 s40648-019-0132-3.pdf: 42402 characters of relevant content
# 📘 s41598-025-89897-y.pdf: 12685 characters of relevant content
# 📘 sensors-18-017861.pdf: 31200 characters of relevant content
# 📘 sensors-22-05261.pdf: 57414 characters of relevant content
# 📘 sensors-22-07983.pdf: 60300 characters of relevant content
# 📘 sensors-23-08298-v2.pdf: 54346 characters of relevant content
# 📘 Soft_Robotic_Grippers_for_Crop_Handling_or_Harvesting_A_Review.pdf: 83763 characters of relevant content

# %%
# === 8. Run analysis in parallel ===
results = {}
splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=100)
print(f"Procesando {len(joined_docs)} documentos en paralelo...\n")

def process_document(doc_name, full_text):
    from langchain_ollama import OllamaLLM
    from langchain.prompts import PromptTemplate
    from langchain.text_splitter import RecursiveCharacterTextSplitter

    # Modelo más rápido
    llm = OllamaLLM(model="llama2:7b-chat", temperature=0.2)

    # Detectar idioma
    lang = "es" if "es" in doc_name.lower() or "spa" in doc_name.lower() else "en"
    prompt_template = PromptTemplate(input_variables=["doc"], template=template_es if lang == "es" else template_en)
    chain = prompt_template | llm

    # Dividir en chunks y agrupar de a 3
    splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
    raw_chunks = splitter.split_text(full_text)
    relevant_chunks = [c for c in raw_chunks if is_relevant_page(c)]
    grouped_chunks = ["\n\n".join(relevant_chunks[i:i+3]) for i in range(0, len(relevant_chunks), 3)]

    arms, grippers = [], []
    print(f"Procesando: {doc_name} ({len(grouped_chunks)} grupos de chunks)")

    for i, group in enumerate(grouped_chunks):
        cleaned = clean_chunk_text(group).replace("\u2028", " ").replace("\u2029", " ")
        try:
            response = chain.invoke({"doc": cleaned})
            print(f"\nRespuesta de {doc_name}, grupo {i+1}:\n{response[:800]}")
            parsed = clean_json_response(response)
            if parsed:
                arms.extend(parsed.get("arms", []))
                grippers.extend(parsed.get("grippers", []))
        except Exception as e:
            print(f"Error en {doc_name}, grupo {i+1}: {e}")
    
    return doc_name, {"arms": arms, "grippers": grippers}



with concurrent.futures.ThreadPoolExecutor() as executor:
    futures = [executor.submit(process_document, name, text) for name, text in joined_docs.items()]
    for future in concurrent.futures.as_completed(futures):
        doc_name, result = future.result()
        results[doc_name] = result

with open(cache_path, "w", encoding="utf-8") as f:
    json.dump(results, f, indent=2, ensure_ascii=False)

print("Análisis finalizado y resultados guardados.\n")
# Out:
# Procesando 37 documentos en paralelo...
#
# Procesando: 1-s2.0-S2405896321018991-main.pdf (5 grupos de chunks)
# Procesando: 1-s2.0-S221478532205307X-main.pdf (8 grupos de chunks)
# Procesando: 1-s2.0-S0921889025000703-main.pdf (13 grupos de chunks)
# Procesando: 131467.pdf (3 grupos de chunks)
# Procesando: Article SOFMER_CharlotteLEGOFF.pdf (8 grupos de chunks)
# Procesando: 1cd20f074aaf0287a4bbcaceebb585fd3e71.pdf (17 grupos de chunks)
# Procesando: 2401.10702v1.pdf (23 grupos de chunks)
# Procesando: annurev-control-060117-105003.pdf (23 grupos de chunks)
# Procesando: Design_and_Development_of_a_Prototype_Robotic_Grip.pdf (6 grupos de chunks)
# Procesando: actuators-14-00124.pdf (21 grupos de chunks)
# Error en 131467.pdf, grupo 1: model 'llama2:7b-chat' not found (status code: 404)
# Error en 1-s2.0-S2405896321018991-main.pdf, grupo 1: model 'llama2:7b-chat' not found (status code: 404)
# Error en 1cd20f074aaf0287a4bbcaceebb585fd3e71.pdf, grupo 1: model 'llama2:7b-chat' not found (status code: 404)
# Error en Article SOFMER_CharlotteLEGOFF.pdf, grupo 1: model 'llama2:7b-chat' not found (status code: 404)
# Procesando: e37ije1673.pdf (8 grupos de chunks)
# Error en annurev-control-060117-105003.pdf, grupo 1: model 'llama2:7b-chat' not found (status code: 404)
# Procesando: ASSISTIVE ROBOTIC ARM.pdf (11 grupos de chunks)
# Procesando: 2109.10892v3.pdf (12 grupos de chunks)
# Error en 1-s2.0-S2405896321018991-main.pdf, grupo 2: model 'llama2:7b-chat' not found (status code: 404)
# Procesando: cooper2020.pdf (6 grupos de chunks)
# Error en 1-s2.0-S221478532205307X-main.pdf, grupo 1: model 'llama2:7b-chat' not found (status code: 404)
# Procesando: electronics-10-00793-v2.pdf (6 grupos de chunks)
# Procesando: 2020-J-RAL-OmniGripper.pdf (20 grupos de chunks)
# Procesando: fnbot-18-1337608.pdf (22 grupos de chunks)
# Error en Article SOFMER_CharlotteLEGOFF.pdf, grupo 2: model 'llama2:7b-chat' not found (status code: 404)
# Error en 1-s2.0-S0921889025000703-main.pdf, grupo 1: model 'llama2:7b-chat' not found (status code: 404)
# Procesando: frobt-06-00147.pdf (12 grupos de chunks)
# Procesando: 3711936.pdf (28 grupos de chunks)
# Error en 2401.10702v1.pdf, grupo 1: model 'llama2:7b-chat' not found (status code: 404)
# Error en ASSISTIVE ROBOTIC ARM.pdf, grupo 1: model 'llama2:7b-chat' not found (status code: 404)
# Error en 1-s2.0-S0921889025000703-main.pdf, grupo 2: model 'llama2:7b-chat' not found (status code: 404)
# Error en 1-s2.0-S2405896321018991-main.pdf, grupo 3: model 'llama2:7b-chat' not found (status code: 404)
# Error en Design_and_Development_of_a_Prototype_Robotic_Grip.pdf, grupo 1: model 'llama2:7b-chat' not found (status code: 404)
# Error en 131467.pdf, grupo 2: model 'llama2:7b-chat' not found (status code: 404)
# Error en cooper2020.pdf, grupo 1: model 'llama2:7b-chat' not found (status code: 404)
# Error en e37ije1673.pdf, grupo 1: model 'llama2:7b-chat' not found (status code: 404)
# Error en 1-s2.0-S2405896321018991-main.pdf, grupo 4: model 'llama2:7b-chat' not found (status code: 404)
# Error en Article SOFMER_CharlotteLEGOFF.pdf, grupo 3: model 'llama2:7b-chat' not found (status code: 404)
# Procesando: gushi2020.pdf (5 grupos de chunks)
# Error en 2401.10702v1.pdf, grupo 2: model 'llama2:7b-chat' not found (status code: 404)
# Error en 1-s2.0-S221478532205307X-main.pdf, grupo 2: model 'llama2:7b-chat' not found (status code: 404)
# Error en cooper2020.pdf, grupo 2: model 'llama2:7b-chat' not found (status code: 404)
# Error en 131467.pdf, grupo 3: model 'llama2:7b-chat' not found (status code: 404)Error en frobt-06-00147.pdf, grupo 1: model 'llama2:7b-chat' not found (status code: 404)
# Error en Design_and_Development_of_a_Prototype_Robotic_Grip.pdf, grupo 2: model 'llama2:7b-chat' not found (status code: 404)
# Error en 1cd20f074aaf0287a4bbcaceebb585fd3e71.pdf, grupo 2: model 'llama2:7b-chat' not found (status code: 404)
# Error en 2401.10702v1.pdf, grupo 3: model 'llama2:7b-chat' not found (status code: 404)
# Error en 1-s2.0-S0921889025000703-main.pdf, grupo 3: model 'llama2:7b-chat' not found (status code: 404)
#
# Error en actuators-14-00124.pdf, grupo 1: model 'llama2:7b-chat' not found (status code: 404)
# Error en electronics-10-00793-v2.pdf, grupo 1: model 'llama2:7b-chat' not found (status code: 404)
# Error en e37ije1673.pdf, grupo 2: model 'llama2:7b-chat' not found (status code: 404)
# Error en 1-s2.0-S221478532205307X-main.pdf, grupo 3: model 'llama2:7b-chat' not found (status code: 404)
# Error en cooper2020.pdf, grupo 3: model 'llama2:7b-chat' not found (status code: 404)
# Error en 1-s2.0-S2405896321018991-main.pdf, grupo 5: model 'llama2:7b-chat' not found (status code: 404)
# Error en Article SOFMER_CharlotteLEGOFF.pdf, grupo 4: model 'llama2:7b-chat' not found (status code: 404)
# Error en 3711936.pdf, grupo 1: model 'llama2:7b-chat' not found (status code: 404)
# Error en fnbot-18-1337608.pdf, grupo 1: model 'llama2:7b-chat' not found (status code: 404)
# Error en annurev-control-060117-105003.pdf, grupo 2: model 'llama2:7b-chat' not found (status code: 404)
# Error en electronics-10-00793-v2.pdf, grupo 2: model 'llama2:7b-chat' not found (status code: 404)
# Error en 1-s2.0-S0921889025000703-main.pdf, grupo 4: model 'llama2:7b-chat' not found (status code: 404)
# Error en actuators-14-00124.pdf, grupo 2: model 'llama2:7b-chat' not found (status code: 404)
# Error en frobt-06-00147.pdf, grupo 2: model 'llama2:7b-chat' not found (status code: 404)
# Error en 1-s2.0-S221478532205307X-main.pdf, grupo 4: model 'llama2:7b-chat' not found (status code: 404)
# Error en 3711936.pdf, grupo 2: model 'llama2:7b-chat' not found (status code: 404)
# Error en Article SOFMER_CharlotteLEGOFF.pdf, grupo 5: model 'llama2:7b-chat' not found (status code: 404)
# Error en 2109.10892v3.pdf, grupo 1: model 'llama2:7b-chat' not found (status code: 404)
# Error en 2401.10702v1.pdf, grupo 4: model 'llama2:7b-chat' not found (status code: 404)
# Error en ASSISTIVE ROBOTIC ARM.pdf, grupo 2: model 'llama2:7b-chat' not found (status code: 404)
# Error en fnbot-18-1337608.pdf, grupo 2: model 'llama2:7b-chat' not found (status code: 404)
# Error en 2020-J-RAL-OmniGripper.pdf, grupo 1: model 'llama2:7b-chat' not found (status code: 404)
# Error en e37ije1673.pdf, grupo 3: model 'llama2:7b-chat' not found (status code: 404)
# Error en 1cd20f074aaf0287a4bbcaceebb585fd3e71.pdf, grupo 3: model 'llama2:7b-chat' not found (status code: 404)
# Error en actuators-14-00124.pdf, grupo 3: model 'llama2:7b-chat' not found (status code: 404)
# Error en 1-s2.0-S0921889025000703-main.pdf, grupo 5: model 'llama2:7b-chat' not found (status code: 404)
# Error en electronics-10-00793-v2.pdf, grupo 3: model 'llama2:7b-chat' not found (status code: 404)
# Error en gushi2020.pdf, grupo 1: model 'llama2:7b-chat' not found (status code: 404)
# Error en Design_and_Development_of_a_Prototype_Robotic_Grip.pdf, grupo 3: model 'llama2:7b-chat' not found (status code: 404)
# Error en annurev-control-060117-105003.pdf, grupo 3: model 'llama2:7b-chat' not found (status code: 404)
# Error en cooper2020.pdf, grupo 4: model 'llama2:7b-chat' not found (status code: 404)
# Error en frobt-06-00147.pdf, grupo 3: model 'llama2:7b-chat' not found (status code: 404)
# Error en e37ije1673.pdf, grupo 4: model 'llama2:7b-chat' not found (status code: 404)
# Error en electronics-10-00793-v2.pdf, grupo 4: model 'llama2:7b-chat' not found (status code: 404)
# Error en 1cd20f074aaf0287a4bbcaceebb585fd3e71.pdf, grupo 4: model 'llama2:7b-chat' not found (status code: 404)
# Error en gushi2020.pdf, grupo 2: model 'llama2:7b-chat' not found (status code: 404)
# Error en 2109.10892v3.pdf, grupo 2: model 'llama2:7b-chat' not found (status code: 404)
# Error en cooper2020.pdf, grupo 5: model 'llama2:7b-chat' not found (status code: 404)
# Error en 1cd20f074aaf0287a4bbcaceebb585fd3e71.pdf, grupo 5: model 'llama2:7b-chat' not found (status code: 404)
# Error en 1-s2.0-S0921889025000703-main.pdf, grupo 6: model 'llama2:7b-chat' not found (status code: 404)
# Error en actuators-14-00124.pdf, grupo 4: model 'llama2:7b-chat' not found (status code: 404)
# Error en electronics-10-00793-v2.pdf, grupo 5: model 'llama2:7b-chat' not found (status code: 404)
# Error en 2020-J-RAL-OmniGripper.pdf, grupo 2: model 'llama2:7b-chat' not found (status code: 404)
# Error en ASSISTIVE ROBOTIC ARM.pdf, grupo 3: model 'llama2:7b-chat' not found (status code: 404)
# Error en 1-s2.0-S0921889025000703-main.pdf, grupo 7: model 'llama2:7b-chat' not found (status code: 404)
# Error en Design_and_Development_of_a_Prototype_Robotic_Grip.pdf, grupo 4: model 'llama2:7b-chat' not found (status code: 404)
# Error en gushi2020.pdf, grupo 3: model 'llama2:7b-chat' not found (status code: 404)
# Error en actuators-14-00124.pdf, grupo 5: model 'llama2:7b-chat' not found (status code: 404)
# Error en 2401.10702v1.pdf, grupo 5: model 'llama2:7b-chat' not found (status code: 404)
# Error en frobt-06-00147.pdf, grupo 4: model 'llama2:7b-chat' not found (status code: 404)
# Error en annurev-control-060117-105003.pdf, grupo 4: model 'llama2:7b-chat' not found (status code: 404)
# Error en 1-s2.0-S221478532205307X-main.pdf, grupo 5: model 'llama2:7b-chat' not found (status code: 404)
# Error en Article SOFMER_CharlotteLEGOFF.pdf, grupo 6: model 'llama2:7b-chat' not found (status code: 404)
# Error en fnbot-18-1337608.pdf, grupo 3: model 'llama2:7b-chat' not found (status code: 404)
# Error en ASSISTIVE ROBOTIC ARM.pdf, grupo 4: model 'llama2:7b-chat' not found (status code: 404)
# Procesando: icce24.pdf (4 grupos de chunks)
# Error en electronics-10-00793-v2.pdf, grupo 6: model 'llama2:7b-chat' not found (status code: 404)
# Error en 2109.10892v3.pdf, grupo 3: model 'llama2:7b-chat' not found (status code: 404)
# Error en cooper2020.pdf, grupo 6: model 'llama2:7b-chat' not found (status code: 404)
# Error en frobt-06-00147.pdf, grupo 5: model 'llama2:7b-chat' not found (status code: 404)
# Error en 1-s2.0-S0921889025000703-main.pdf, grupo 8: model 'llama2:7b-chat' not found (status code: 404)
# Error en fnbot-18-1337608.pdf, grupo 4: model 'llama2:7b-chat' not found (status code: 404)
# Error en 2020-J-RAL-OmniGripper.pdf, grupo 3: model 'llama2:7b-chat' not found (status code: 404)
# Error en 1cd20f074aaf0287a4bbcaceebb585fd3e71.pdf, grupo 6: model 'llama2:7b-chat' not found (status code: 404)
# Error en e37ije1673.pdf, grupo 5: model 'llama2:7b-chat' not found (status code: 404)
# Error en 3711936.pdf, grupo 3: model 'llama2:7b-chat' not found (status code: 404)
# Procesando: Humanoid robots for assisting people with physical disabilities in activities of daily living  A scoping review.pdf (28 grupos de chunks)
# Error en actuators-14-00124.pdf, grupo 6: model 'llama2:7b-chat' not found (status code: 404)
# Error en Article SOFMER_CharlotteLEGOFF.pdf, grupo 7: model 'llama2:7b-chat' not found (status code: 404)
# Error en 1-s2.0-S221478532205307X-main.pdf, grupo 6: model 'llama2:7b-chat' not found (status code: 404)
# Error en 1cd20f074aaf0287a4bbcaceebb585fd3e71.pdf, grupo 7: model 'llama2:7b-chat' not found (status code: 404)
# Error en ASSISTIVE ROBOTIC ARM.pdf, grupo 5: model 'llama2:7b-chat' not found (status code: 404)
# Error en 3711936.pdf, grupo 4: model 'llama2:7b-chat' not found (status code: 404)
# Error en Design_and_Development_of_a_Prototype_Robotic_Grip.pdf, grupo 5: model 'llama2:7b-chat' not found (status code: 404)
# Error en Article SOFMER_CharlotteLEGOFF.pdf, grupo 8: model 'llama2:7b-chat' not found (status code: 404)
# Error en e37ije1673.pdf, grupo 6: model 'llama2:7b-chat' not found (status code: 404)
# Error en 1-s2.0-S221478532205307X-main.pdf, grupo 7: model 'llama2:7b-chat' not found (status code: 404)
# Error en 2020-J-RAL-OmniGripper.pdf, grupo 4: model 'llama2:7b-chat' not found (status code: 404)
# Error en actuators-14-00124.pdf, grupo 7: model 'llama2:7b-chat' not found (status code: 404)
# Error en 2109.10892v3.pdf, grupo 4: model 'llama2:7b-chat' not found (status code: 404)
# Error en fnbot-18-1337608.pdf, grupo 5: model 'llama2:7b-chat' not found (status code: 404)
# Error en 3711936.pdf, grupo 5: model 'llama2:7b-chat' not found (status code: 404)
# Error en gushi2020.pdf, grupo 4: model 'llama2:7b-chat' not found (status code: 404)
# Error en 2020-J-RAL-OmniGripper.pdf, grupo 5: model 'llama2:7b-chat' not found (status code: 404)
# Error en gushi2020.pdf, grupo 5: model 'llama2:7b-chat' not found (status code: 404)
# Error en 1-s2.0-S0921889025000703-main.pdf, grupo 9: model 'llama2:7b-chat' not found (status code: 404)
# Error en 2109.10892v3.pdf, grupo 5: model 'llama2:7b-chat' not found (status code: 404)
# Error en 1-s2.0-S221478532205307X-main.pdf, grupo 8: model 'llama2:7b-chat' not found (status code: 404)
# Error en Design_and_Development_of_a_Prototype_Robotic_Grip.pdf, grupo 6: model 'llama2:7b-chat' not found (status code: 404)
# Error en ASSISTIVE ROBOTIC ARM.pdf, grupo 6: model 'llama2:7b-chat' not found (status code: 404)
# Error en 2401.10702v1.pdf, grupo 6: model 'llama2:7b-chat' not found (status code: 404)
# Error en icce24.pdf, grupo 1: model 'llama2:7b-chat' not found (status code: 404)
# Error en 2020-J-RAL-OmniGripper.pdf, grupo 6: model 'llama2:7b-chat' not found (status code: 404)
# Error en annurev-control-060117-105003.pdf, grupo 5: model 'llama2:7b-chat' not found (status code: 404)
# Error en 2109.10892v3.pdf, grupo 6: model 'llama2:7b-chat' not found (status code: 404)
# Error en actuators-14-00124.pdf, grupo 8: model 'llama2:7b-chat' not found (status code: 404)
# Error en Humanoid robots for assisting people with physical disabilities in activities of daily living  A scoping review.pdf, grupo 1: model 'llama2:7b-chat' not found (status code: 404)
# Error en frobt-06-00147.pdf, grupo 6: model 'llama2:7b-chat' not found (status code: 404)
# Error en icce24.pdf, grupo 2: model 'llama2:7b-chat' not found (status code: 404)
# Error en 3711936.pdf, grupo 6: model 'llama2:7b-chat' not found (status code: 404)
# Error en actuators-14-00124.pdf, grupo 9: model 'llama2:7b-chat' not found (status code: 404)
# Error en frobt-06-00147.pdf, grupo 7: model 'llama2:7b-chat' not found (status code: 404)
# Error en annurev-control-060117-105003.pdf, grupo 6: model 'llama2:7b-chat' not found (status code: 404)
# Error en e37ije1673.pdf, grupo 7: model 'llama2:7b-chat' not found (status code: 404)
# Procesando: IRJET_Pick_and_Place_Robotic_Arm_A_Revie.pdf (12 grupos de chunks)
# Error en 2401.10702v1.pdf, grupo 7: model 'llama2:7b-chat' not found (status code: 404)
# Procesando: li-et-al-2022-a-review-on-structural-development-and-recognition-localization-methods-for-end-effector-of-fruit.pdf (43 grupos de chunks)
# Error en 2020-J-RAL-OmniGripper.pdf, grupo 7: model 'llama2:7b-chat' not found (status code: 404)
# Error en Humanoid robots for assisting people with physical disabilities in activities of daily living  A scoping review.pdf, grupo 2: model 'llama2:7b-chat' not found (status code: 404)Error en 2401.10702v1.pdf, grupo 8: model 'llama2:7b-chat' not found (status code: 404)
# Error en fnbot-18-1337608.pdf, grupo 6: model 'llama2:7b-chat' not found (status code: 404)
# Error en 1cd20f074aaf0287a4bbcaceebb585fd3e71.pdf, grupo 8: model 'llama2:7b-chat' not found (status code: 404)
# Error en actuators-14-00124.pdf, grupo 10: model 'llama2:7b-chat' not found (status code: 404)
# Error en 3711936.pdf, grupo 7: model 'llama2:7b-chat' not found (status code: 404)Error en 1-s2.0-S0921889025000703-main.pdf, grupo 10: model 'llama2:7b-chat' not found (status code: 404)
# Error en annurev-control-060117-105003.pdf, grupo 7: model 'llama2:7b-chat' not found (status code: 404)Error en IRJET_Pick_and_Place_Robotic_Arm_A_Revie.pdf, grupo 1: model 'llama2:7b-chat' not found (status code: 404)Error en e37ije1673.pdf, grupo 8: model 'llama2:7b-chat' not found (status code: 404)Error en icce24.pdf, grupo 3: model 'llama2:7b-chat' not found (status code: 404)
# Error en 2020-J-RAL-OmniGripper.pdf, grupo 8: model 'llama2:7b-chat' not found (status code: 404)
#
# Error en 2401.10702v1.pdf, grupo 9: model 'llama2:7b-chat' not found (status code: 404)Error en 2109.10892v3.pdf, grupo 7: model 'llama2:7b-chat' not found (status code: 404)
# Error en Humanoid robots for assisting people with physical disabilities in activities of daily living  A scoping review.pdf, grupo 3: model 'llama2:7b-chat' not found (status code: 404)
# Error en actuators-14-00124.pdf, grupo 11: model 'llama2:7b-chat' not found (status code: 404)Error en ASSISTIVE ROBOTIC ARM.pdf, grupo 7: model 'llama2:7b-chat' not found (status code: 404)
#
#
# Error en frobt-06-00147.pdf, grupo 8: model 'llama2:7b-chat' not found (status code: 404)Error en 1-s2.0-S0921889025000703-main.pdf, grupo 11: model 'llama2:7b-chat' not found (status code: 404)
# Error en li-et-al-2022-a-review-on-structural-development-and-recognition-localization-methods-for-end-effector-of-fruit.pdf, grupo 1: model 'llama2:7b-chat' not found (status code: 404)Error en icce24.pdf, grupo 4: model 'llama2:7b-chat' not found (status code: 404)
# Error en fnbot-18-1337608.pdf, grupo 7: model 'llama2:7b-chat' not found (status code: 404)
# Error en 1cd20f074aaf0287a4bbcaceebb585fd3e71.pdf, grupo 9: model 'llama2:7b-chat' not found (status code: 404)
#
# Error en 3711936.pdf, grupo 8: model 'llama2:7b-chat' not found (status code: 404)
#
#
# Error en ASSISTIVE ROBOTIC ARM.pdf, grupo 8: model 'llama2:7b-chat' not found (status code: 404)
# Error en annurev-control-060117-105003.pdf, grupo 8: model 'llama2:7b-chat' not found (status code: 404)Error en 1-s2.0-S0921889025000703-main.pdf, grupo 12: model 'llama2:7b-chat' not found (status code: 404)
# Error en 2020-J-RAL-OmniGripper.pdf, grupo 9: model 'llama2:7b-chat' not found (status code: 404)
# Error en 2109.10892v3.pdf, grupo 8: model 'llama2:7b-chat' not found (status code: 404)
# Error en fnbot-18-1337608.pdf, grupo 8: model 'llama2:7b-chat' not found (status code: 404)Error en 3711936.pdf, grupo 9: model 'llama2:7b-chat' not found (status code: 404)Error en IRJET_Pick_and_Place_Robotic_Arm_A_Revie.pdf, grupo 2: model 'llama2:7b-chat' not found (status code: 404)Error en frobt-06-00147.pdf, grupo 9: model 'llama2:7b-chat' not found (status code: 404)
#
# Error en 2401.10702v1.pdf, grupo 10: model 'llama2:7b-chat' not found (status code: 404)
# Error en actuators-14-00124.pdf, grupo 12: model 'llama2:7b-chat' not found (status code: 404)Error en Humanoid robots for assisting people with physical disabilities in activities of daily living  A scoping review.pdf, grupo 4: model 'llama2:7b-chat' not found (status code: 404)
# Error en li-et-al-2022-a-review-on-structural-development-and-recognition-localization-methods-for-end-effector-of-fruit.pdf, grupo 2: model 'llama2:7b-chat' not found (status code: 404)
#
#
# Error en 2109.10892v3.pdf, grupo 9: model 'llama2:7b-chat' not found (status code: 404)
# Error en 1cd20f074aaf0287a4bbcaceebb585fd3e71.pdf, grupo 10: model 'llama2:7b-chat' not found (status code: 404)
# Procesando: ReMAR2024_Murgia_Long_Caro.pdf (5 grupos de chunks)Error en 1-s2.0-S0921889025000703-main.pdf, grupo 13: model 'llama2:7b-chat' not found (status code: 404)
# Procesando: PAPRAS_Plug-And-Play_Robotic_Arm_System.pdf (12 grupos de chunks)Error en annurev-control-060117-105003.pdf, grupo 9: model 'llama2:7b-chat' not found (status code: 404)
#
# Error en Humanoid robots for assisting people with physical disabilities in activities of daily living  A scoping review.pdf, grupo 5: model 'llama2:7b-chat' not found (status code: 404)
# Procesando: robotics-11-00127-v2.pdf (25 grupos de chunks)
# Error en 2020-J-RAL-OmniGripper.pdf, grupo 10: model 'llama2:7b-chat' not found (status code: 404)Error en fnbot-18-1337608.pdf, grupo 9: model 'llama2:7b-chat' not found (status code: 404)
# Error en IRJET_Pick_and_Place_Robotic_Arm_A_Revie.pdf, grupo 3: model 'llama2:7b-chat' not found (status code: 404)
#
#
# Error en frobt-06-00147.pdf, grupo 10: model 'llama2:7b-chat' not found (status code: 404)
#
# Error en 1cd20f074aaf0287a4bbcaceebb585fd3e71.pdf, grupo 11: model 'llama2:7b-chat' not found (status code: 404)Error en actuators-14-00124.pdf, grupo 13: model 'llama2:7b-chat' not found (status code: 404)
# Error en ASSISTIVE ROBOTIC ARM.pdf, grupo 9: model 'llama2:7b-chat' not found (status code: 404)
# Procesando: robotics-12-00005-v2.pdf (54 grupos de chunks)Error en li-et-al-2022-a-review-on-structural-development-and-recognition-localization-methods-for-end-effector-of-fruit.pdf, grupo 3: model 'llama2:7b-chat' not found (status code: 404)Error en 2109.10892v3.pdf, grupo 10: model 'llama2:7b-chat' not found (status code: 404)
# Error en 3711936.pdf, grupo 10: model 'llama2:7b-chat' not found (status code: 404)Error en robotics-11-00127-v2.pdf, grupo 1: model 'llama2:7b-chat' not found (status code: 404)
# Error en fnbot-18-1337608.pdf, grupo 10: model 'llama2:7b-chat' not found (status code: 404)
#
# Error en ReMAR2024_Murgia_Long_Caro.pdf, grupo 1: model 'llama2:7b-chat' not found (status code: 404)Error en annurev-control-060117-105003.pdf, grupo 10: model 'llama2:7b-chat' not found (status code: 404)
#
#
# Error en actuators-14-00124.pdf, grupo 14: model 'llama2:7b-chat' not found (status code: 404)
#
#
#
# Error en 2401.10702v1.pdf, grupo 11: model 'llama2:7b-chat' not found (status code: 404)
# Error en PAPRAS_Plug-And-Play_Robotic_Arm_System.pdf, grupo 1: model 'llama2:7b-chat' not found (status code: 404)
#
# Error en fnbot-18-1337608.pdf, grupo 11: model 'llama2:7b-chat' not found (status code: 404)Procesando: s10846-022-01781-3.pdf (9 grupos de chunks)
# Error en 1cd20f074aaf0287a4bbcaceebb585fd3e71.pdf, grupo 12: model 'llama2:7b-chat' not found (status code: 404)
# Procesando: s12369-021-00816-3.pdf (19 grupos de chunks)Error en Humanoid robots for assisting people with physical disabilities in activities of daily living  A scoping review.pdf, grupo 6: model 'llama2:7b-chat' not found (status code: 404)Error en ASSISTIVE ROBOTIC ARM.pdf, grupo 10: model 'llama2:7b-chat' not found (status code: 404)Error en 2020-J-RAL-OmniGripper.pdf, grupo 11: model 'llama2:7b-chat' not found (status code: 404)Error en li-et-al-2022-a-review-on-structural-development-and-recognition-localization-methods-for-end-effector-of-fruit.pdf, grupo 4: model 'llama2:7b-chat' not found (status code: 404)
# Error en 2109.10892v3.pdf, grupo 11: model 'llama2:7b-chat' not found (status code: 404)Error en IRJET_Pick_and_Place_Robotic_Arm_A_Revie.pdf, grupo 4: model 'llama2:7b-chat' not found (status code: 404)
# Error en actuators-14-00124.pdf, grupo 15: model 'llama2:7b-chat' not found (status code: 404)
#
#
# Error en PAPRAS_Plug-And-Play_Robotic_Arm_System.pdf, grupo 2: model 'llama2:7b-chat' not found (status code: 404)Error en 3711936.pdf, grupo 11: model 'llama2:7b-chat' not found (status code: 404)Error en 2401.10702v1.pdf, grupo 12: model 'llama2:7b-chat' not found (status code: 404)
# Error en frobt-06-00147.pdf, grupo 11: model 'llama2:7b-chat' not found (status code: 404)
#
#
#
# Error en robotics-12-00005-v2.pdf, grupo 1: model 'llama2:7b-chat' not found (status code: 404)
# Error en annurev-control-060117-105003.pdf, grupo 11: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-11-00127-v2.pdf, grupo 2: model 'llama2:7b-chat' not found (status code: 404)Error en IRJET_Pick_and_Place_Robotic_Arm_A_Revie.pdf, grupo 5: model 'llama2:7b-chat' not found (status code: 404)
# Error en li-et-al-2022-a-review-on-structural-development-and-recognition-localization-methods-for-end-effector-of-fruit.pdf, grupo 5: model 'llama2:7b-chat' not found (status code: 404)
#
# Error en ReMAR2024_Murgia_Long_Caro.pdf, grupo 2: model 'llama2:7b-chat' not found (status code: 404)
#
# Error en s10846-022-01781-3.pdf, grupo 1: model 'llama2:7b-chat' not found (status code: 404)Error en 2401.10702v1.pdf, grupo 13: model 'llama2:7b-chat' not found (status code: 404)
#
#
# Procesando: s40648-019-0132-3.pdf (9 grupos de chunks)
# Error en fnbot-18-1337608.pdf, grupo 12: model 'llama2:7b-chat' not found (status code: 404)Error en ASSISTIVE ROBOTIC ARM.pdf, grupo 11: model 'llama2:7b-chat' not found (status code: 404)
#
# Error en IRJET_Pick_and_Place_Robotic_Arm_A_Revie.pdf, grupo 6: model 'llama2:7b-chat' not found (status code: 404)
# Error en annurev-control-060117-105003.pdf, grupo 12: model 'llama2:7b-chat' not found (status code: 404)Error en s12369-021-00816-3.pdf, grupo 1: model 'llama2:7b-chat' not found (status code: 404)
# Error en li-et-al-2022-a-review-on-structural-development-and-recognition-localization-methods-for-end-effector-of-fruit.pdf, grupo 6: model 'llama2:7b-chat' not found (status code: 404)
# Error en 1cd20f074aaf0287a4bbcaceebb585fd3e71.pdf, grupo 13: model 'llama2:7b-chat' not found (status code: 404)Error en ReMAR2024_Murgia_Long_Caro.pdf, grupo 3: model 'llama2:7b-chat' not found (status code: 404)
#
# Error en 2401.10702v1.pdf, grupo 14: model 'llama2:7b-chat' not found (status code: 404)Error en robotics-12-00005-v2.pdf, grupo 2: model 'llama2:7b-chat' not found (status code: 404)
#
# Error en Humanoid robots for assisting people with physical disabilities in activities of daily living  A scoping review.pdf, grupo 7: model 'llama2:7b-chat' not found (status code: 404)
# Error en 2020-J-RAL-OmniGripper.pdf, grupo 12: model 'llama2:7b-chat' not found (status code: 404)
# Error en PAPRAS_Plug-And-Play_Robotic_Arm_System.pdf, grupo 3: model 'llama2:7b-chat' not found (status code: 404)
# Error en IRJET_Pick_and_Place_Robotic_Arm_A_Revie.pdf, grupo 7: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-11-00127-v2.pdf, grupo 3: model 'llama2:7b-chat' not found (status code: 404)
# Error en s12369-021-00816-3.pdf, grupo 2: model 'llama2:7b-chat' not found (status code: 404)
# Error en 3711936.pdf, grupo 12: model 'llama2:7b-chat' not found (status code: 404)
#
# Error en actuators-14-00124.pdf, grupo 16: model 'llama2:7b-chat' not found (status code: 404)
# Error en 2109.10892v3.pdf, grupo 12: model 'llama2:7b-chat' not found (status code: 404)
#
# Error en li-et-al-2022-a-review-on-structural-development-and-recognition-localization-methods-for-end-effector-of-fruit.pdf, grupo 7: model 'llama2:7b-chat' not found (status code: 404)
# Error en 2020-J-RAL-OmniGripper.pdf, grupo 13: model 'llama2:7b-chat' not found (status code: 404)Error en Humanoid robots for assisting people with physical disabilities in activities of daily living  A scoping review.pdf, grupo 8: model 'llama2:7b-chat' not found (status code: 404)
# Error en frobt-06-00147.pdf, grupo 12: model 'llama2:7b-chat' not found (status code: 404)
#
#
# Error en s12369-021-00816-3.pdf, grupo 3: model 'llama2:7b-chat' not found (status code: 404)
# Error en 3711936.pdf, grupo 13: model 'llama2:7b-chat' not found (status code: 404)Error en robotics-12-00005-v2.pdf, grupo 3: model 'llama2:7b-chat' not found (status code: 404)
# Error en 2401.10702v1.pdf, grupo 15: model 'llama2:7b-chat' not found (status code: 404)
# Error en actuators-14-00124.pdf, grupo 17: model 'llama2:7b-chat' not found (status code: 404)
# Error en PAPRAS_Plug-And-Play_Robotic_Arm_System.pdf, grupo 4: model 'llama2:7b-chat' not found (status code: 404)
# Error en fnbot-18-1337608.pdf, grupo 13: model 'llama2:7b-chat' not found (status code: 404)
# Error en Humanoid robots for assisting people with physical disabilities in activities of daily living  A scoping review.pdf, grupo 9: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-11-00127-v2.pdf, grupo 4: model 'llama2:7b-chat' not found (status code: 404)
# Error en annurev-control-060117-105003.pdf, grupo 13: model 'llama2:7b-chat' not found (status code: 404)
# Error en 1cd20f074aaf0287a4bbcaceebb585fd3e71.pdf, grupo 14: model 'llama2:7b-chat' not found (status code: 404)
# Error en s12369-021-00816-3.pdf, grupo 4: model 'llama2:7b-chat' not found (status code: 404)
#
# Error en 2401.10702v1.pdf, grupo 16: model 'llama2:7b-chat' not found (status code: 404)Error en actuators-14-00124.pdf, grupo 18: model 'llama2:7b-chat' not found (status code: 404)
# Error en IRJET_Pick_and_Place_Robotic_Arm_A_Revie.pdf, grupo 8: model 'llama2:7b-chat' not found (status code: 404)
# Error en s40648-019-0132-3.pdf, grupo 1: model 'llama2:7b-chat' not found (status code: 404)Error en li-et-al-2022-a-review-on-structural-development-and-recognition-localization-methods-for-end-effector-of-fruit.pdf, grupo 8: model 'llama2:7b-chat' not found (status code: 404)Error en robotics-12-00005-v2.pdf, grupo 4: model 'llama2:7b-chat' not found (status code: 404)Error en Humanoid robots for assisting people with physical disabilities in activities of daily living  A scoping review.pdf, grupo 10: model 'llama2:7b-chat' not found (status code: 404)Error en fnbot-18-1337608.pdf, grupo 14: model 'llama2:7b-chat' not found (status code: 404)Error en robotics-11-00127-v2.pdf, grupo 5: model 'llama2:7b-chat' not found (status code: 404)
# Error en PAPRAS_Plug-And-Play_Robotic_Arm_System.pdf, grupo 5: model 'llama2:7b-chat' not found (status code: 404)Error en annurev-control-060117-105003.pdf, grupo 14: model 'llama2:7b-chat' not found (status code: 404)
#
# Error en 2020-J-RAL-OmniGripper.pdf, grupo 14: model 'llama2:7b-chat' not found (status code: 404)Error en s10846-022-01781-3.pdf, grupo 2: model 'llama2:7b-chat' not found (status code: 404)
#
#
# Error en actuators-14-00124.pdf, grupo 19: model 'llama2:7b-chat' not found (status code: 404)
#
#
# Error en 3711936.pdf, grupo 14: model 'llama2:7b-chat' not found (status code: 404)
# Error en ReMAR2024_Murgia_Long_Caro.pdf, grupo 4: model 'llama2:7b-chat' not found (status code: 404)
# Error en s12369-021-00816-3.pdf, grupo 5: model 'llama2:7b-chat' not found (status code: 404)Error en robotics-11-00127-v2.pdf, grupo 6: model 'llama2:7b-chat' not found (status code: 404)
# Error en 1cd20f074aaf0287a4bbcaceebb585fd3e71.pdf, grupo 15: model 'llama2:7b-chat' not found (status code: 404)
# Error en annurev-control-060117-105003.pdf, grupo 15: model 'llama2:7b-chat' not found (status code: 404)
#
# Procesando: s41598-025-89897-y.pdf (3 grupos de chunks)Error en IRJET_Pick_and_Place_Robotic_Arm_A_Revie.pdf, grupo 9: model 'llama2:7b-chat' not found (status code: 404)
# Error en s10846-022-01781-3.pdf, grupo 3: model 'llama2:7b-chat' not found (status code: 404)Error en li-et-al-2022-a-review-on-structural-development-and-recognition-localization-methods-for-end-effector-of-fruit.pdf, grupo 9: model 'llama2:7b-chat' not found (status code: 404)
# Error en s40648-019-0132-3.pdf, grupo 2: model 'llama2:7b-chat' not found (status code: 404)
# Error en Humanoid robots for assisting people with physical disabilities in activities of daily living  A scoping review.pdf, grupo 11: model 'llama2:7b-chat' not found (status code: 404)
# Error en ReMAR2024_Murgia_Long_Caro.pdf, grupo 5: model 'llama2:7b-chat' not found (status code: 404)
# Error en 2401.10702v1.pdf, grupo 17: model 'llama2:7b-chat' not found (status code: 404)
# Procesando: sensors-18-017861.pdf (6 grupos de chunks)
# Error en robotics-11-00127-v2.pdf, grupo 7: model 'llama2:7b-chat' not found (status code: 404)
#
#
# Error en IRJET_Pick_and_Place_Robotic_Arm_A_Revie.pdf, grupo 10: model 'llama2:7b-chat' not found (status code: 404)
# Error en annurev-control-060117-105003.pdf, grupo 16: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-12-00005-v2.pdf, grupo 5: model 'llama2:7b-chat' not found (status code: 404)
# Error en s12369-021-00816-3.pdf, grupo 6: model 'llama2:7b-chat' not found (status code: 404)
# Error en s40648-019-0132-3.pdf, grupo 3: model 'llama2:7b-chat' not found (status code: 404)
#
# Error en 2020-J-RAL-OmniGripper.pdf, grupo 15: model 'llama2:7b-chat' not found (status code: 404)
# Error en actuators-14-00124.pdf, grupo 20: model 'llama2:7b-chat' not found (status code: 404)
# Error en PAPRAS_Plug-And-Play_Robotic_Arm_System.pdf, grupo 6: model 'llama2:7b-chat' not found (status code: 404)
#
# Error en 1cd20f074aaf0287a4bbcaceebb585fd3e71.pdf, grupo 16: model 'llama2:7b-chat' not found (status code: 404)
# Procesando: sensors-22-05261.pdf (14 grupos de chunks)
# Error en IRJET_Pick_and_Place_Robotic_Arm_A_Revie.pdf, grupo 11: model 'llama2:7b-chat' not found (status code: 404)
# Error en annurev-control-060117-105003.pdf, grupo 17: model 'llama2:7b-chat' not found (status code: 404)
# Error en s12369-021-00816-3.pdf, grupo 7: model 'llama2:7b-chat' not found (status code: 404)
# Error en Humanoid robots for assisting people with physical disabilities in activities of daily living  A scoping review.pdf, grupo 12: model 'llama2:7b-chat' not found (status code: 404)Error en s10846-022-01781-3.pdf, grupo 4: model 'llama2:7b-chat' not found (status code: 404)Error en 2020-J-RAL-OmniGripper.pdf, grupo 16: model 'llama2:7b-chat' not found (status code: 404)
# Error en sensors-18-017861.pdf, grupo 1: model 'llama2:7b-chat' not found (status code: 404)Error en actuators-14-00124.pdf, grupo 21: model 'llama2:7b-chat' not found (status code: 404)
# Error en PAPRAS_Plug-And-Play_Robotic_Arm_System.pdf, grupo 7: model 'llama2:7b-chat' not found (status code: 404)
# Error en 3711936.pdf, grupo 15: model 'llama2:7b-chat' not found (status code: 404)Error en s41598-025-89897-y.pdf, grupo 1: model 'llama2:7b-chat' not found (status code: 404)
# Error en fnbot-18-1337608.pdf, grupo 15: model 'llama2:7b-chat' not found (status code: 404)
#
# Error en 1cd20f074aaf0287a4bbcaceebb585fd3e71.pdf, grupo 17: model 'llama2:7b-chat' not found (status code: 404)
#
# Error en s12369-021-00816-3.pdf, grupo 8: model 'llama2:7b-chat' not found (status code: 404)
# Error en sensors-22-05261.pdf, grupo 1: model 'llama2:7b-chat' not found (status code: 404)
# Error en annurev-control-060117-105003.pdf, grupo 18: model 'llama2:7b-chat' not found (status code: 404)
#
#
# Error en 2020-J-RAL-OmniGripper.pdf, grupo 17: model 'llama2:7b-chat' not found (status code: 404)
# Error en IRJET_Pick_and_Place_Robotic_Arm_A_Revie.pdf, grupo 12: model 'llama2:7b-chat' not found (status code: 404)
# Error en 2401.10702v1.pdf, grupo 18: model 'llama2:7b-chat' not found (status code: 404)Error en s41598-025-89897-y.pdf, grupo 2: model 'llama2:7b-chat' not found (status code: 404)
# Error en fnbot-18-1337608.pdf, grupo 16: model 'llama2:7b-chat' not found (status code: 404)
# Error en Humanoid robots for assisting people with physical disabilities in activities of daily living  A scoping review.pdf, grupo 13: model 'llama2:7b-chat' not found (status code: 404)
# Error en li-et-al-2022-a-review-on-structural-development-and-recognition-localization-methods-for-end-effector-of-fruit.pdf, grupo 10: model 'llama2:7b-chat' not found (status code: 404)Error en s12369-021-00816-3.pdf, grupo 9: model 'llama2:7b-chat' not found (status code: 404)
# Procesando: sensors-22-07983.pdf (18 grupos de chunks)Error en s10846-022-01781-3.pdf, grupo 5: model 'llama2:7b-chat' not found (status code: 404)Error en PAPRAS_Plug-And-Play_Robotic_Arm_System.pdf, grupo 8: model 'llama2:7b-chat' not found (status code: 404)
#
#
# Error en 3711936.pdf, grupo 16: model 'llama2:7b-chat' not found (status code: 404)
# Error en sensors-22-05261.pdf, grupo 2: model 'llama2:7b-chat' not found (status code: 404)
# Error en s40648-019-0132-3.pdf, grupo 4: model 'llama2:7b-chat' not found (status code: 404)
#
# Error en s41598-025-89897-y.pdf, grupo 3: model 'llama2:7b-chat' not found (status code: 404)
#
#
# Error en sensors-18-017861.pdf, grupo 2: model 'llama2:7b-chat' not found (status code: 404)
#
# Error en PAPRAS_Plug-And-Play_Robotic_Arm_System.pdf, grupo 9: model 'llama2:7b-chat' not found (status code: 404)Error en s12369-021-00816-3.pdf, grupo 10: model 'llama2:7b-chat' not found (status code: 404)
# Error en 2020-J-RAL-OmniGripper.pdf, grupo 18: model 'llama2:7b-chat' not found (status code: 404)Error en 2401.10702v1.pdf, grupo 19: model 'llama2:7b-chat' not found (status code: 404)
# Error en fnbot-18-1337608.pdf, grupo 17: model 'llama2:7b-chat' not found (status code: 404)Error en annurev-control-060117-105003.pdf, grupo 19: model 'llama2:7b-chat' not found (status code: 404)
# Error en 3711936.pdf, grupo 17: model 'llama2:7b-chat' not found (status code: 404)
# Error en sensors-22-05261.pdf, grupo 3: model 'llama2:7b-chat' not found (status code: 404)
#
# Error en s10846-022-01781-3.pdf, grupo 6: model 'llama2:7b-chat' not found (status code: 404)Error en li-et-al-2022-a-review-on-structural-development-and-recognition-localization-methods-for-end-effector-of-fruit.pdf, grupo 11: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-11-00127-v2.pdf, grupo 8: model 'llama2:7b-chat' not found (status code: 404)
# Error en s40648-019-0132-3.pdf, grupo 5: model 'llama2:7b-chat' not found (status code: 404)Error en s12369-021-00816-3.pdf, grupo 11: model 'llama2:7b-chat' not found (status code: 404)
# Error en Humanoid robots for assisting people with physical disabilities in activities of daily living  A scoping review.pdf, grupo 14: model 'llama2:7b-chat' not found (status code: 404)Error en robotics-12-00005-v2.pdf, grupo 6: model 'llama2:7b-chat' not found (status code: 404)
# Error en 2401.10702v1.pdf, grupo 20: model 'llama2:7b-chat' not found (status code: 404)
# Error en sensors-22-05261.pdf, grupo 4: model 'llama2:7b-chat' not found (status code: 404)
# Error en annurev-control-060117-105003.pdf, grupo 20: model 'llama2:7b-chat' not found (status code: 404)
#
#
# Error en li-et-al-2022-a-review-on-structural-development-and-recognition-localization-methods-for-end-effector-of-fruit.pdf, grupo 12: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-11-00127-v2.pdf, grupo 9: model 'llama2:7b-chat' not found (status code: 404)Error en PAPRAS_Plug-And-Play_Robotic_Arm_System.pdf, grupo 10: model 'llama2:7b-chat' not found (status code: 404)
# Error en sensors-18-017861.pdf, grupo 3: model 'llama2:7b-chat' not found (status code: 404)
#
# Error en robotics-12-00005-v2.pdf, grupo 7: model 'llama2:7b-chat' not found (status code: 404)Procesando: sensors-23-08298-v2.pdf (28 grupos de chunks)
# Error en sensors-22-07983.pdf, grupo 1: model 'llama2:7b-chat' not found (status code: 404)
# Error en annurev-control-060117-105003.pdf, grupo 21: model 'llama2:7b-chat' not found (status code: 404)
# Error en s10846-022-01781-3.pdf, grupo 7: model 'llama2:7b-chat' not found (status code: 404)
# Error en s40648-019-0132-3.pdf, grupo 6: model 'llama2:7b-chat' not found (status code: 404)
#
#
# Error en fnbot-18-1337608.pdf, grupo 18: model 'llama2:7b-chat' not found (status code: 404)Procesando: Soft_Robotic_Grippers_for_Crop_Handling_or_Harvesting_A_Review.pdf (48 grupos de chunks)
#
# Error en sensors-18-017861.pdf, grupo 4: model 'llama2:7b-chat' not found (status code: 404)Error en 2401.10702v1.pdf, grupo 21: model 'llama2:7b-chat' not found (status code: 404)
# Error en sensors-22-05261.pdf, grupo 5: model 'llama2:7b-chat' not found (status code: 404)
# Error en 2020-J-RAL-OmniGripper.pdf, grupo 19: model 'llama2:7b-chat' not found (status code: 404)
# Error en li-et-al-2022-a-review-on-structural-development-and-recognition-localization-methods-for-end-effector-of-fruit.pdf, grupo 13: model 'llama2:7b-chat' not found (status code: 404)
# Error en s40648-019-0132-3.pdf, grupo 7: model 'llama2:7b-chat' not found (status code: 404)
#
# Error en s10846-022-01781-3.pdf, grupo 8: model 'llama2:7b-chat' not found (status code: 404)
# Error en 3711936.pdf, grupo 18: model 'llama2:7b-chat' not found (status code: 404)
# Error en PAPRAS_Plug-And-Play_Robotic_Arm_System.pdf, grupo 11: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-12-00005-v2.pdf, grupo 8: model 'llama2:7b-chat' not found (status code: 404)
# Error en sensors-23-08298-v2.pdf, grupo 1: model 'llama2:7b-chat' not found (status code: 404)
# Error en sensors-22-07983.pdf, grupo 2: model 'llama2:7b-chat' not found (status code: 404)
# Error en 2020-J-RAL-OmniGripper.pdf, grupo 20: model 'llama2:7b-chat' not found (status code: 404)
# Error en sensors-22-05261.pdf, grupo 6: model 'llama2:7b-chat' not found (status code: 404)
# Error en annurev-control-060117-105003.pdf, grupo 22: model 'llama2:7b-chat' not found (status code: 404)
#
#
# Error en fnbot-18-1337608.pdf, grupo 19: model 'llama2:7b-chat' not found (status code: 404)Error en s10846-022-01781-3.pdf, grupo 9: model 'llama2:7b-chat' not found (status code: 404)
# Error en Humanoid robots for assisting people with physical disabilities in activities of daily living  A scoping review.pdf, grupo 15: model 'llama2:7b-chat' not found (status code: 404)
# Error en 3711936.pdf, grupo 19: model 'llama2:7b-chat' not found (status code: 404)Error en s12369-021-00816-3.pdf, grupo 12: model 'llama2:7b-chat' not found (status code: 404)
# Error en sensors-22-07983.pdf, grupo 3: model 'llama2:7b-chat' not found (status code: 404)
# Error en sensors-23-08298-v2.pdf, grupo 2: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-12-00005-v2.pdf, grupo 9: model 'llama2:7b-chat' not found (status code: 404)
#
# Error en annurev-control-060117-105003.pdf, grupo 23: model 'llama2:7b-chat' not found (status code: 404)Error en robotics-11-00127-v2.pdf, grupo 10: model 'llama2:7b-chat' not found (status code: 404)
# Error en sensors-18-017861.pdf, grupo 5: model 'llama2:7b-chat' not found (status code: 404)
# Error en Soft_Robotic_Grippers_for_Crop_Handling_or_Harvesting_A_Review.pdf, grupo 1: model 'llama2:7b-chat' not found (status code: 404)
# Error en s40648-019-0132-3.pdf, grupo 8: model 'llama2:7b-chat' not found (status code: 404)
# Error en Humanoid robots for assisting people with physical disabilities in activities of daily living  A scoping review.pdf, grupo 16: model 'llama2:7b-chat' not found (status code: 404)
# Error en sensors-22-05261.pdf, grupo 7: model 'llama2:7b-chat' not found (status code: 404)
#
# Error en fnbot-18-1337608.pdf, grupo 20: model 'llama2:7b-chat' not found (status code: 404)
# Error en sensors-22-07983.pdf, grupo 4: model 'llama2:7b-chat' not found (status code: 404)
# Error en sensors-23-08298-v2.pdf, grupo 3: model 'llama2:7b-chat' not found (status code: 404)
# Error en li-et-al-2022-a-review-on-structural-development-and-recognition-localization-methods-for-end-effector-of-fruit.pdf, grupo 14: model 'llama2:7b-chat' not found (status code: 404)
# Error en 2401.10702v1.pdf, grupo 22: model 'llama2:7b-chat' not found (status code: 404)
# Error en Soft_Robotic_Grippers_for_Crop_Handling_or_Harvesting_A_Review.pdf, grupo 2: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-12-00005-v2.pdf, grupo 10: model 'llama2:7b-chat' not found (status code: 404)
# Error en Humanoid robots for assisting people with physical disabilities in activities of daily living  A scoping review.pdf, grupo 17: model 'llama2:7b-chat' not found (status code: 404)
#
# Error en fnbot-18-1337608.pdf, grupo 21: model 'llama2:7b-chat' not found (status code: 404)Error en robotics-11-00127-v2.pdf, grupo 11: model 'llama2:7b-chat' not found (status code: 404)
# Error en sensors-18-017861.pdf, grupo 6: model 'llama2:7b-chat' not found (status code: 404)
# Error en sensors-23-08298-v2.pdf, grupo 4: model 'llama2:7b-chat' not found (status code: 404)Error en s40648-019-0132-3.pdf, grupo 9: model 'llama2:7b-chat' not found (status code: 404)
# Error en PAPRAS_Plug-And-Play_Robotic_Arm_System.pdf, grupo 12: model 'llama2:7b-chat' not found (status code: 404)
# Error en sensors-22-05261.pdf, grupo 8: model 'llama2:7b-chat' not found (status code: 404)
# Error en Humanoid robots for assisting people with physical disabilities in activities of daily living  A scoping review.pdf, grupo 18: model 'llama2:7b-chat' not found (status code: 404)
# Error en sensors-22-07983.pdf, grupo 5: model 'llama2:7b-chat' not found (status code: 404)
# Error en 3711936.pdf, grupo 20: model 'llama2:7b-chat' not found (status code: 404)
#
# Error en robotics-11-00127-v2.pdf, grupo 12: model 'llama2:7b-chat' not found (status code: 404)
# Error en li-et-al-2022-a-review-on-structural-development-and-recognition-localization-methods-for-end-effector-of-fruit.pdf, grupo 15: model 'llama2:7b-chat' not found (status code: 404)
#
# Error en s12369-021-00816-3.pdf, grupo 13: model 'llama2:7b-chat' not found (status code: 404)
# Error en sensors-22-05261.pdf, grupo 9: model 'llama2:7b-chat' not found (status code: 404)
# Error en Soft_Robotic_Grippers_for_Crop_Handling_or_Harvesting_A_Review.pdf, grupo 3: model 'llama2:7b-chat' not found (status code: 404)Error en 2401.10702v1.pdf, grupo 23: model 'llama2:7b-chat' not found (status code: 404)
# Error en 3711936.pdf, grupo 21: model 'llama2:7b-chat' not found (status code: 404)
# Error en sensors-23-08298-v2.pdf, grupo 5: model 'llama2:7b-chat' not found (status code: 404)
# Error en Humanoid robots for assisting people with physical disabilities in activities of daily living  A scoping review.pdf, grupo 19: model 'llama2:7b-chat' not found (status code: 404)
# Error en li-et-al-2022-a-review-on-structural-development-and-recognition-localization-methods-for-end-effector-of-fruit.pdf, grupo 16: model 'llama2:7b-chat' not found (status code: 404)
# Error en sensors-22-05261.pdf, grupo 10: model 'llama2:7b-chat' not found (status code: 404)Error en robotics-12-00005-v2.pdf, grupo 11: model 'llama2:7b-chat' not found (status code: 404)
# Error en s12369-021-00816-3.pdf, grupo 14: model 'llama2:7b-chat' not found (status code: 404)
# Error en sensors-22-07983.pdf, grupo 6: model 'llama2:7b-chat' not found (status code: 404)
#
#
# Error en sensors-23-08298-v2.pdf, grupo 6: model 'llama2:7b-chat' not found (status code: 404)
# Error en Humanoid robots for assisting people with physical disabilities in activities of daily living  A scoping review.pdf, grupo 20: model 'llama2:7b-chat' not found (status code: 404)Error en fnbot-18-1337608.pdf, grupo 22: model 'llama2:7b-chat' not found (status code: 404)
# Error en Soft_Robotic_Grippers_for_Crop_Handling_or_Harvesting_A_Review.pdf, grupo 4: model 'llama2:7b-chat' not found (status code: 404)Error en 3711936.pdf, grupo 22: model 'llama2:7b-chat' not found (status code: 404)
# Error en s12369-021-00816-3.pdf, grupo 15: model 'llama2:7b-chat' not found (status code: 404)
# Error en li-et-al-2022-a-review-on-structural-development-and-recognition-localization-methods-for-end-effector-of-fruit.pdf, grupo 17: model 'llama2:7b-chat' not found (status code: 404)
# Error en sensors-22-05261.pdf, grupo 11: model 'llama2:7b-chat' not found (status code: 404)Error en sensors-23-08298-v2.pdf, grupo 7: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-12-00005-v2.pdf, grupo 12: model 'llama2:7b-chat' not found (status code: 404)
# Error en sensors-22-07983.pdf, grupo 7: model 'llama2:7b-chat' not found (status code: 404)
#
# Error en s12369-021-00816-3.pdf, grupo 16: model 'llama2:7b-chat' not found (status code: 404)
# Error en Humanoid robots for assisting people with physical disabilities in activities of daily living  A scoping review.pdf, grupo 21: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-11-00127-v2.pdf, grupo 13: model 'llama2:7b-chat' not found (status code: 404)
#
# Error en sensors-23-08298-v2.pdf, grupo 8: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-12-00005-v2.pdf, grupo 13: model 'llama2:7b-chat' not found (status code: 404)Error en sensors-22-07983.pdf, grupo 8: model 'llama2:7b-chat' not found (status code: 404)
# Error en Soft_Robotic_Grippers_for_Crop_Handling_or_Harvesting_A_Review.pdf, grupo 5: model 'llama2:7b-chat' not found (status code: 404)
# Error en Humanoid robots for assisting people with physical disabilities in activities of daily living  A scoping review.pdf, grupo 22: model 'llama2:7b-chat' not found (status code: 404)
# Error en li-et-al-2022-a-review-on-structural-development-and-recognition-localization-methods-for-end-effector-of-fruit.pdf, grupo 18: model 'llama2:7b-chat' not found (status code: 404)
# Error en 3711936.pdf, grupo 23: model 'llama2:7b-chat' not found (status code: 404)Error en sensors-23-08298-v2.pdf, grupo 9: model 'llama2:7b-chat' not found (status code: 404)Error en sensors-22-05261.pdf, grupo 12: model 'llama2:7b-chat' not found (status code: 404)
#
#
#
#
# ...
# Error en sensors-22-07983.pdf, grupo 13: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-12-00005-v2.pdf, grupo 16: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-11-00127-v2.pdf, grupo 19: model 'llama2:7b-chat' not found (status code: 404)
# Error en li-et-al-2022-a-review-on-structural-development-and-recognition-localization-methods-for-end-effector-of-fruit.pdf, grupo 23: model 'llama2:7b-chat' not found (status code: 404)Error en 3711936.pdf, grupo 28: model 'llama2:7b-chat' not found (status code: 404)Error en Humanoid robots for assisting people with physical disabilities in activities of daily living  A scoping review.pdf, grupo 28: model 'llama2:7b-chat' not found (status code: 404)
# Error en sensors-22-07983.pdf, grupo 14: model 'llama2:7b-chat' not found (status code: 404)
#
# Error en robotics-12-00005-v2.pdf, grupo 17: model 'llama2:7b-chat' not found (status code: 404)
#
# Error en robotics-11-00127-v2.pdf, grupo 20: model 'llama2:7b-chat' not found (status code: 404)
# Error en sensors-23-08298-v2.pdf, grupo 15: model 'llama2:7b-chat' not found (status code: 404)
# Error en sensors-22-07983.pdf, grupo 15: model 'llama2:7b-chat' not found (status code: 404)
# Error en Soft_Robotic_Grippers_for_Crop_Handling_or_Harvesting_A_Review.pdf, grupo 11: model 'llama2:7b-chat' not found (status code: 404)
# Error en li-et-al-2022-a-review-on-structural-development-and-recognition-localization-methods-for-end-effector-of-fruit.pdf, grupo 24: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-12-00005-v2.pdf, grupo 18: model 'llama2:7b-chat' not found (status code: 404)
# Error en sensors-23-08298-v2.pdf, grupo 16: model 'llama2:7b-chat' not found (status code: 404)Error en sensors-22-07983.pdf, grupo 16: model 'llama2:7b-chat' not found (status code: 404)
#
# Error en Soft_Robotic_Grippers_for_Crop_Handling_or_Harvesting_A_Review.pdf, grupo 12: model 'llama2:7b-chat' not found (status code: 404)
# Error en li-et-al-2022-a-review-on-structural-development-and-recognition-localization-methods-for-end-effector-of-fruit.pdf, grupo 25: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-11-00127-v2.pdf, grupo 21: model 'llama2:7b-chat' not found (status code: 404)
# Error en sensors-22-07983.pdf, grupo 17: model 'llama2:7b-chat' not found (status code: 404)
# Error en Soft_Robotic_Grippers_for_Crop_Handling_or_Harvesting_A_Review.pdf, grupo 13: model 'llama2:7b-chat' not found (status code: 404)
# Error en sensors-23-08298-v2.pdf, grupo 17: model 'llama2:7b-chat' not found (status code: 404)Error en li-et-al-2022-a-review-on-structural-development-and-recognition-localization-methods-for-end-effector-of-fruit.pdf, grupo 26: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-11-00127-v2.pdf, grupo 22: model 'llama2:7b-chat' not found (status code: 404)
#
# Error en robotics-12-00005-v2.pdf, grupo 19: model 'llama2:7b-chat' not found (status code: 404)
# Error en sensors-22-07983.pdf, grupo 18: model 'llama2:7b-chat' not found (status code: 404)
# Error en li-et-al-2022-a-review-on-structural-development-and-recognition-localization-methods-for-end-effector-of-fruit.pdf, grupo 27: model 'llama2:7b-chat' not found (status code: 404)
# Error en Soft_Robotic_Grippers_for_Crop_Handling_or_Harvesting_A_Review.pdf, grupo 14: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-12-00005-v2.pdf, grupo 20: model 'llama2:7b-chat' not found (status code: 404)Error en robotics-11-00127-v2.pdf, grupo 23: model 'llama2:7b-chat' not found (status code: 404)
# Error en li-et-al-2022-a-review-on-structural-development-and-recognition-localization-methods-for-end-effector-of-fruit.pdf, grupo 28: model 'llama2:7b-chat' not found (status code: 404)
# Error en sensors-23-08298-v2.pdf, grupo 18: model 'llama2:7b-chat' not found (status code: 404)
#
# Error en Soft_Robotic_Grippers_for_Crop_Handling_or_Harvesting_A_Review.pdf, grupo 15: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-11-00127-v2.pdf, grupo 24: model 'llama2:7b-chat' not found (status code: 404)Error en sensors-23-08298-v2.pdf, grupo 19: model 'llama2:7b-chat' not found (status code: 404)
# Error en li-et-al-2022-a-review-on-structural-development-and-recognition-localization-methods-for-end-effector-of-fruit.pdf, grupo 29: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-12-00005-v2.pdf, grupo 21: model 'llama2:7b-chat' not found (status code: 404)
# Error en Soft_Robotic_Grippers_for_Crop_Handling_or_Harvesting_A_Review.pdf, grupo 16: model 'llama2:7b-chat' not found (status code: 404)
# Error en sensors-23-08298-v2.pdf, grupo 20: model 'llama2:7b-chat' not found (status code: 404)Error en li-et-al-2022-a-review-on-structural-development-and-recognition-localization-methods-for-end-effector-of-fruit.pdf, grupo 30: model 'llama2:7b-chat' not found (status code: 404)
#
#
# Error en robotics-12-00005-v2.pdf, grupo 22: model 'llama2:7b-chat' not found (status code: 404)
# Error en Soft_Robotic_Grippers_for_Crop_Handling_or_Harvesting_A_Review.pdf, grupo 17: model 'llama2:7b-chat' not found (status code: 404)
# Error en li-et-al-2022-a-review-on-structural-development-and-recognition-localization-methods-for-end-effector-of-fruit.pdf, grupo 31: model 'llama2:7b-chat' not found (status code: 404)
# Error en sensors-23-08298-v2.pdf, grupo 21: model 'llama2:7b-chat' not found (status code: 404)
# Error en sensors-23-08298-v2.pdf, grupo 22: model 'llama2:7b-chat' not found (status code: 404)
# Error en Soft_Robotic_Grippers_for_Crop_Handling_or_Harvesting_A_Review.pdf, grupo 18: model 'llama2:7b-chat' not found (status code: 404)
# Error en sensors-23-08298-v2.pdf, grupo 23: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-11-00127-v2.pdf, grupo 25: model 'llama2:7b-chat' not found (status code: 404)
# Error en li-et-al-2022-a-review-on-structural-development-and-recognition-localization-methods-for-end-effector-of-fruit.pdf, grupo 32: model 'llama2:7b-chat' not found (status code: 404)
# Error en Soft_Robotic_Grippers_for_Crop_Handling_or_Harvesting_A_Review.pdf, grupo 19: model 'llama2:7b-chat' not found (status code: 404)
# Error en sensors-23-08298-v2.pdf, grupo 24: model 'llama2:7b-chat' not found (status code: 404)
# Error en li-et-al-2022-a-review-on-structural-development-and-recognition-localization-methods-for-end-effector-of-fruit.pdf, grupo 33: model 'llama2:7b-chat' not found (status code: 404)
# Error en Soft_Robotic_Grippers_for_Crop_Handling_or_Harvesting_A_Review.pdf, grupo 20: model 'llama2:7b-chat' not found (status code: 404)
# Error en sensors-23-08298-v2.pdf, grupo 25: model 'llama2:7b-chat' not found (status code: 404)
# Error en li-et-al-2022-a-review-on-structural-development-and-recognition-localization-methods-for-end-effector-of-fruit.pdf, grupo 34: model 'llama2:7b-chat' not found (status code: 404)
# Error en Soft_Robotic_Grippers_for_Crop_Handling_or_Harvesting_A_Review.pdf, grupo 21: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-12-00005-v2.pdf, grupo 23: model 'llama2:7b-chat' not found (status code: 404)
# Error en li-et-al-2022-a-review-on-structural-development-and-recognition-localization-methods-for-end-effector-of-fruit.pdf, grupo 35: model 'llama2:7b-chat' not found (status code: 404)
# Error en sensors-23-08298-v2.pdf, grupo 26: model 'llama2:7b-chat' not found (status code: 404)
# Error en Soft_Robotic_Grippers_for_Crop_Handling_or_Harvesting_A_Review.pdf, grupo 22: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-12-00005-v2.pdf, grupo 24: model 'llama2:7b-chat' not found (status code: 404)
# Error en Soft_Robotic_Grippers_for_Crop_Handling_or_Harvesting_A_Review.pdf, grupo 23: model 'llama2:7b-chat' not found (status code: 404)
# Error en sensors-23-08298-v2.pdf, grupo 27: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-12-00005-v2.pdf, grupo 25: model 'llama2:7b-chat' not found (status code: 404)
# Error en li-et-al-2022-a-review-on-structural-development-and-recognition-localization-methods-for-end-effector-of-fruit.pdf, grupo 36: model 'llama2:7b-chat' not found (status code: 404)
# Error en Soft_Robotic_Grippers_for_Crop_Handling_or_Harvesting_A_Review.pdf, grupo 24: model 'llama2:7b-chat' not found (status code: 404)
# Error en sensors-23-08298-v2.pdf, grupo 28: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-12-00005-v2.pdf, grupo 26: model 'llama2:7b-chat' not found (status code: 404)
# Error en li-et-al-2022-a-review-on-structural-development-and-recognition-localization-methods-for-end-effector-of-fruit.pdf, grupo 37: model 'llama2:7b-chat' not found (status code: 404)
# Error en Soft_Robotic_Grippers_for_Crop_Handling_or_Harvesting_A_Review.pdf, grupo 25: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-12-00005-v2.pdf, grupo 27: model 'llama2:7b-chat' not found (status code: 404)
# Error en li-et-al-2022-a-review-on-structural-development-and-recognition-localization-methods-for-end-effector-of-fruit.pdf, grupo 38: model 'llama2:7b-chat' not found (status code: 404)
# Error en Soft_Robotic_Grippers_for_Crop_Handling_or_Harvesting_A_Review.pdf, grupo 26: model 'llama2:7b-chat' not found (status code: 404)
# Error en li-et-al-2022-a-review-on-structural-development-and-recognition-localization-methods-for-end-effector-of-fruit.pdf, grupo 39: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-12-00005-v2.pdf, grupo 28: model 'llama2:7b-chat' not found (status code: 404)
# Error en Soft_Robotic_Grippers_for_Crop_Handling_or_Harvesting_A_Review.pdf, grupo 27: model 'llama2:7b-chat' not found (status code: 404)
# Error en li-et-al-2022-a-review-on-structural-development-and-recognition-localization-methods-for-end-effector-of-fruit.pdf, grupo 40: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-12-00005-v2.pdf, grupo 29: model 'llama2:7b-chat' not found (status code: 404)
# Error en Soft_Robotic_Grippers_for_Crop_Handling_or_Harvesting_A_Review.pdf, grupo 28: model 'llama2:7b-chat' not found (status code: 404)
# Error en li-et-al-2022-a-review-on-structural-development-and-recognition-localization-methods-for-end-effector-of-fruit.pdf, grupo 41: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-12-00005-v2.pdf, grupo 30: model 'llama2:7b-chat' not found (status code: 404)
# Error en Soft_Robotic_Grippers_for_Crop_Handling_or_Harvesting_A_Review.pdf, grupo 29: model 'llama2:7b-chat' not found (status code: 404)
# Error en li-et-al-2022-a-review-on-structural-development-and-recognition-localization-methods-for-end-effector-of-fruit.pdf, grupo 42: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-12-00005-v2.pdf, grupo 31: model 'llama2:7b-chat' not found (status code: 404)
# Error en Soft_Robotic_Grippers_for_Crop_Handling_or_Harvesting_A_Review.pdf, grupo 30: model 'llama2:7b-chat' not found (status code: 404)
# Error en li-et-al-2022-a-review-on-structural-development-and-recognition-localization-methods-for-end-effector-of-fruit.pdf, grupo 43: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-12-00005-v2.pdf, grupo 32: model 'llama2:7b-chat' not found (status code: 404)
# Error en Soft_Robotic_Grippers_for_Crop_Handling_or_Harvesting_A_Review.pdf, grupo 31: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-12-00005-v2.pdf, grupo 33: model 'llama2:7b-chat' not found (status code: 404)
# Error en Soft_Robotic_Grippers_for_Crop_Handling_or_Harvesting_A_Review.pdf, grupo 32: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-12-00005-v2.pdf, grupo 34: model 'llama2:7b-chat' not found (status code: 404)
# Error en Soft_Robotic_Grippers_for_Crop_Handling_or_Harvesting_A_Review.pdf, grupo 33: model 'llama2:7b-chat' not found (status code: 404)
# Error en Soft_Robotic_Grippers_for_Crop_Handling_or_Harvesting_A_Review.pdf, grupo 34: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-12-00005-v2.pdf, grupo 35: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-12-00005-v2.pdf, grupo 36: model 'llama2:7b-chat' not found (status code: 404)
# Error en Soft_Robotic_Grippers_for_Crop_Handling_or_Harvesting_A_Review.pdf, grupo 35: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-12-00005-v2.pdf, grupo 37: model 'llama2:7b-chat' not found (status code: 404)
# Error en Soft_Robotic_Grippers_for_Crop_Handling_or_Harvesting_A_Review.pdf, grupo 36: model 'llama2:7b-chat' not found (status code: 404)
# Error en Soft_Robotic_Grippers_for_Crop_Handling_or_Harvesting_A_Review.pdf, grupo 37: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-12-00005-v2.pdf, grupo 38: model 'llama2:7b-chat' not found (status code: 404)
# Error en Soft_Robotic_Grippers_for_Crop_Handling_or_Harvesting_A_Review.pdf, grupo 38: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-12-00005-v2.pdf, grupo 39: model 'llama2:7b-chat' not found (status code: 404)
# Error en Soft_Robotic_Grippers_for_Crop_Handling_or_Harvesting_A_Review.pdf, grupo 39: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-12-00005-v2.pdf, grupo 40: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-12-00005-v2.pdf, grupo 41: model 'llama2:7b-chat' not found (status code: 404)
# Error en Soft_Robotic_Grippers_for_Crop_Handling_or_Harvesting_A_Review.pdf, grupo 40: model 'llama2:7b-chat' not found (status code: 404)
# Error en Soft_Robotic_Grippers_for_Crop_Handling_or_Harvesting_A_Review.pdf, grupo 41: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-12-00005-v2.pdf, grupo 42: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-12-00005-v2.pdf, grupo 43: model 'llama2:7b-chat' not found (status code: 404)
# Error en Soft_Robotic_Grippers_for_Crop_Handling_or_Harvesting_A_Review.pdf, grupo 42: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-12-00005-v2.pdf, grupo 44: model 'llama2:7b-chat' not found (status code: 404)
# Error en Soft_Robotic_Grippers_for_Crop_Handling_or_Harvesting_A_Review.pdf, grupo 43: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-12-00005-v2.pdf, grupo 45: model 'llama2:7b-chat' not found (status code: 404)
# Error en Soft_Robotic_Grippers_for_Crop_Handling_or_Harvesting_A_Review.pdf, grupo 44: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-12-00005-v2.pdf, grupo 46: model 'llama2:7b-chat' not found (status code: 404)
# Error en Soft_Robotic_Grippers_for_Crop_Handling_or_Harvesting_A_Review.pdf, grupo 45: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-12-00005-v2.pdf, grupo 47: model 'llama2:7b-chat' not found (status code: 404)
# Error en Soft_Robotic_Grippers_for_Crop_Handling_or_Harvesting_A_Review.pdf, grupo 46: model 'llama2:7b-chat' not found (status code: 404)
# Error en Soft_Robotic_Grippers_for_Crop_Handling_or_Harvesting_A_Review.pdf, grupo 47: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-12-00005-v2.pdf, grupo 48: model 'llama2:7b-chat' not found (status code: 404)
# Error en Soft_Robotic_Grippers_for_Crop_Handling_or_Harvesting_A_Review.pdf, grupo 48: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-12-00005-v2.pdf, grupo 49: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-12-00005-v2.pdf, grupo 50: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-12-00005-v2.pdf, grupo 51: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-12-00005-v2.pdf, grupo 52: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-12-00005-v2.pdf, grupo 53: model 'llama2:7b-chat' not found (status code: 404)
# Error en robotics-12-00005-v2.pdf, grupo 54: model 'llama2:7b-chat' not found (status code: 404)
# Análisis finalizado y resultados guardados.

# %%
# === 9. Print all results clearly ===
print("📊 RESULTADOS COMPLETOS:")
for name, data in results.items():
    print(f"\n🗂️ Documento: {name}")
    if data["arms"] or data["grippers"]:
        pprint(data)
    else:
        print("⚠️ No se extrajeron brazos ni grippers.")
# Out:
# 📊 RESULTADOS COMPLETOS:
#
# 🗂️ Documento: 131467.pdf
# ⚠️ No se extrajeron brazos ni grippers.
#
# 🗂️ Documento: 1-s2.0-S2405896321018991-main.pdf
# ⚠️ No se extrajeron brazos ni grippers.
#
# 🗂️ Documento: electronics-10-00793-v2.pdf
# ⚠️ No se extrajeron brazos ni grippers.
#
# 🗂️ Documento: cooper2020.pdf
# ⚠️ No se extrajeron brazos ni grippers.
#
# 🗂️ Documento: Article SOFMER_CharlotteLEGOFF.pdf
# ⚠️ No se extrajeron brazos ni grippers.
#
# 🗂️ Documento: gushi2020.pdf
# ⚠️ No se extrajeron brazos ni grippers.
#
# 🗂️ Documento: 1-s2.0-S221478532205307X-main.pdf
# ⚠️ No se extrajeron brazos ni grippers.
#
# 🗂️ Documento: Design_and_Development_of_a_Prototype_Robotic_Grip.pdf
# ⚠️ No se extrajeron brazos ni grippers.
#
# 🗂️ Documento: e37ije1673.pdf
# ⚠️ No se extrajeron brazos ni grippers.
#
# 🗂️ Documento: icce24.pdf
# ⚠️ No se extrajeron brazos ni grippers.
#
# 🗂️ Documento: 1-s2.0-S0921889025000703-main.pdf
# ⚠️ No se extrajeron brazos ni grippers.
#
# 🗂️ Documento: ASSISTIVE ROBOTIC ARM.pdf
# ⚠️ No se extrajeron brazos ni grippers.
#
# 🗂️ Documento: 2109.10892v3.pdf
# ⚠️ No se extrajeron brazos ni grippers.
#
# 🗂️ Documento: frobt-06-00147.pdf
# ⚠️ No se extrajeron brazos ni grippers.
#
# 🗂️ Documento: ReMAR2024_Murgia_Long_Caro.pdf
# ⚠️ No se extrajeron brazos ni grippers.
#
# 🗂️ Documento: actuators-14-00124.pdf
# ⚠️ No se extrajeron brazos ni grippers.
#
# 🗂️ Documento: IRJET_Pick_and_Place_Robotic_Arm_A_Revie.pdf
# ⚠️ No se extrajeron brazos ni grippers.
#
# 🗂️ Documento: 1cd20f074aaf0287a4bbcaceebb585fd3e71.pdf
# ⚠️ No se extrajeron brazos ni grippers.
#
# 🗂️ Documento: s41598-025-89897-y.pdf
# ⚠️ No se extrajeron brazos ni grippers.
#
# 🗂️ Documento: 2020-J-RAL-OmniGripper.pdf
# ⚠️ No se extrajeron brazos ni grippers.
#
# 🗂️ Documento: s10846-022-01781-3.pdf
# ⚠️ No se extrajeron brazos ni grippers.
#
# 🗂️ Documento: annurev-control-060117-105003.pdf
# ⚠️ No se extrajeron brazos ni grippers.
#
# 🗂️ Documento: sensors-18-017861.pdf
# ⚠️ No se extrajeron brazos ni grippers.
#
# 🗂️ Documento: s40648-019-0132-3.pdf
# ⚠️ No se extrajeron brazos ni grippers.
#
# 🗂️ Documento: PAPRAS_Plug-And-Play_Robotic_Arm_System.pdf
# ⚠️ No se extrajeron brazos ni grippers.
#
# 🗂️ Documento: 2401.10702v1.pdf
# ⚠️ No se extrajeron brazos ni grippers.
#
# 🗂️ Documento: fnbot-18-1337608.pdf
# ⚠️ No se extrajeron brazos ni grippers.
#
# 🗂️ Documento: sensors-22-05261.pdf
# ⚠️ No se extrajeron brazos ni grippers.
#
# 🗂️ Documento: s12369-021-00816-3.pdf
# ⚠️ No se extrajeron brazos ni grippers.
#
# 🗂️ Documento: Humanoid robots for assisting people with physical disabilities in activities of daily living  A scoping review.pdf
# ⚠️ No se extrajeron brazos ni grippers.
#
# 🗂️ Documento: 3711936.pdf
# ⚠️ No se extrajeron brazos ni grippers.
#
# 🗂️ Documento: sensors-22-07983.pdf
# ⚠️ No se extrajeron brazos ni grippers.
#
# 🗂️ Documento: robotics-11-00127-v2.pdf
# ⚠️ No se extrajeron brazos ni grippers.
#
# 🗂️ Documento: sensors-23-08298-v2.pdf
# ⚠️ No se extrajeron brazos ni grippers.
#
# 🗂️ Documento: li-et-al-2022-a-review-on-structural-development-and-recognition-localization-methods-for-end-effector-of-fruit.pdf
# ⚠️ No se extrajeron brazos ni grippers.
#
# 🗂️ Documento: Soft_Robotic_Grippers_for_Crop_Handling_or_Harvesting_A_Review.pdf
# ⚠️ No se extrajeron brazos ni grippers.
#
# 🗂️ Documento: robotics-12-00005-v2.pdf
# ⚠️ No se extrajeron brazos ni grippers.
